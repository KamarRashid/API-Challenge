# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build base url
base_url = 'http://api.openweathermap.org/data/2.5/weather?&units=metric'
# query url
query_url = f'{base_url}&appid={weather_api_key}&q='

# Counters
set_counter = 1

city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
weather_date = []

print ('Beginning Data Retrieval')
print ('------------------------------------')

# Creating a loop to make api calls for each city in our list
for i, city in enumerate (cities):
    
    response = requests.get(query_url+city).json()
    print (f'Processing Record {i} | {city}')
    
    # Try to get the data from API, if no data or city is available, skip that city and continue
    try:
        # retrieve and append lists with data
        city_name.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        weather_date.append((datetime.fromtimestamp(response['dt'])).strftime('%m/%d/%y'))
        
        set_counter += 1
        
    # Handle all exceptions for a city that is not available in the Weather API by passing over it
    except:
        print ('City not found. Skipping...')
        pass
# Out:
# Beginning Data Retrieval
# ------------------------------------
# Processing Record 0 | helong
# Processing Record 1 | bluff
# Processing Record 2 | busselton
# Processing Record 3 | kathmandu
# Processing Record 4 | kefamenanu
# Processing Record 5 | mataura
# Processing Record 6 | krasnoselkup
# Processing Record 7 | saleaula
# City not found. Skipping...
# Processing Record 8 | sisimiut
# Processing Record 9 | puerto ayora
# Processing Record 10 | kapaa
# Processing Record 11 | albany
# Processing Record 12 | castro
# Processing Record 13 | chokurdakh
# Processing Record 14 | saldanha
# Processing Record 15 | ushuaia
# Processing Record 16 | erzin
# Processing Record 17 | lazarev
# Processing Record 18 | severo-yeniseyskiy
# Processing Record 19 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 | atuona
# Processing Record 21 | naze
# Processing Record 22 | port lincoln
# Processing Record 23 | halifax
# Processing Record 24 | port blair
# Processing Record 25 | ranong
# Processing Record 26 | punta arenas
# Processing Record 27 | rikitea
# Processing Record 28 | east london
# Processing Record 29 | tasiilaq
# Processing Record 30 | puerto escondido
# Processing Record 31 | arraial do cabo
# Processing Record 32 | pevek
# Processing Record 33 | nemuro
# Processing Record 34 | bredasdorp
# Processing Record 35 | port alfred
# Processing Record 36 | lebu
# Processing Record 37 | hermanus
# Processing Record 38 | kuche
# City not found. Skipping...
# Processing Record 39 | carnarvon
# Processing Record 40 | esperance
# Processing Record 41 | segezha
# Processing Record 42 | chuy
# Processing Record 43 | turtkul
# City not found. Skipping...
# Processing Record 44 | buraydah
# Processing Record 45 | aklavik
# Processing Record 46 | belushya guba
# City not found. Skipping...
# Processing Record 47 | samusu
# City not found. Skipping...
# Processing Record 48 | san quintin
# Processing Record 49 | sao filipe
# Processing Record 50 | georgetown
# Processing Record 51 | san patricio
# Processing Record 52 | coquimbo
# Processing Record 53 | saint-agapit
# Processing Record 54 | sarnia
# Processing Record 55 | sedelnikovo
# City not found. Skipping...
# Processing Record 56 | salekhard
# Processing Record 57 | talnakh
# Processing Record 58 | saryshagan
# City not found. Skipping...
# Processing Record 59 | guerrero negro
# Processing Record 60 | fare
# Processing Record 61 | visby
# Processing Record 62 | maningrida
# Processing Record 63 | necochea
# Processing Record 64 | uray
# Processing Record 65 | kruisfontein
# Processing Record 66 | hobyo
# Processing Record 67 | touros
# Processing Record 68 | mys shmidta
# City not found. Skipping...
# Processing Record 69 | jardim
# Processing Record 70 | bilibino
# Processing Record 71 | tuxpan
# Processing Record 72 | gobabis
# Processing Record 73 | provideniya
# Processing Record 74 | rasova
# Processing Record 75 | cidreira
# Processing Record 76 | rio de janeiro
# Processing Record 77 | kristiinankaupunki
# Processing Record 78 | megion
# Processing Record 79 | fukue
# Processing Record 80 | ostersund
# Processing Record 81 | lagoa
# Processing Record 82 | yulara
# Processing Record 83 | belaya gora
# Processing Record 84 | severo-kurilsk
# Processing Record 85 | louisbourg
# City not found. Skipping...
# Processing Record 86 | hobart
# Processing Record 87 | tiksi
# Processing Record 88 | taolanaro
# City not found. Skipping...
# Processing Record 89 | chaiyaphum
# Processing Record 90 | kahului
# Processing Record 91 | tuatapere
# Processing Record 92 | picota
# Processing Record 93 | rungata
# City not found. Skipping...
# Processing Record 94 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 95 | seoul
# Processing Record 96 | nalut
# Processing Record 97 | mwene-ditu
# Processing Record 98 | agadir
# Processing Record 99 | dikson
# Processing Record 100 | port elizabeth
# Processing Record 101 | formoso do araguaia
# City not found. Skipping...
# Processing Record 102 | vardo
# Processing Record 103 | bandarbeyla
# Processing Record 104 | nyurba
# Processing Record 105 | kalmunai
# Processing Record 106 | karaul
# City not found. Skipping...
# Processing Record 107 | new kensington
# Processing Record 108 | anadyr
# Processing Record 109 | portland
# Processing Record 110 | cape town
# Processing Record 111 | pimentel
# Processing Record 112 | dabat
# Processing Record 113 | jiangkou
# Processing Record 114 | khatanga
# Processing Record 115 | vila
# Processing Record 116 | pemangkat
# Processing Record 117 | tunxi
# City not found. Skipping...
# Processing Record 118 | comodoro rivadavia
# Processing Record 119 | sakakah
# Processing Record 120 | kavieng
# Processing Record 121 | marsh harbour
# Processing Record 122 | maltahohe
# Processing Record 123 | luanda
# Processing Record 124 | lolua
# City not found. Skipping...
# Processing Record 125 | puerto del rosario
# Processing Record 126 | ponta delgada
# Processing Record 127 | tanout
# Processing Record 128 | rocha
# Processing Record 129 | baturaja
# Processing Record 130 | acapulco
# Processing Record 131 | hvide sande
# Processing Record 132 | haines junction
# Processing Record 133 | burnie
# Processing Record 134 | upernavik
# Processing Record 135 | willowmore
# Processing Record 136 | velikie luki
# City not found. Skipping...
# Processing Record 137 | ilulissat
# Processing Record 138 | salalah
# Processing Record 139 | gat
# Processing Record 140 | kaiu
# Processing Record 141 | lata
# Processing Record 142 | mirnyy
# Processing Record 143 | puro
# Processing Record 144 | sabang
# Processing Record 145 | hilo
# Processing Record 146 | pinsk
# Processing Record 147 | ostrovnoy
# Processing Record 148 | villa carlos paz
# Processing Record 149 | bhim tal
# Processing Record 150 | hamilton
# Processing Record 151 | strezhevoy
# Processing Record 152 | padang
# Processing Record 153 | khandbari
# Processing Record 154 | gorontalo
# Processing Record 155 | trinidad
# Processing Record 156 | tuktoyaktuk
# Processing Record 157 | waipawa
# Processing Record 158 | tilichiki
# Processing Record 159 | sieradz
# Processing Record 160 | bairiki
# Processing Record 161 | tiarei
# Processing Record 162 | nanortalik
# Processing Record 163 | nikolskoye
# Processing Record 164 | san carlos
# Processing Record 165 | timberlake
# Processing Record 166 | aste
# Processing Record 167 | hithadhoo
# Processing Record 168 | komsomolskiy
# Processing Record 169 | hauterive
# Processing Record 170 | thompson
# Processing Record 171 | xam nua
# Processing Record 172 | baykit
# Processing Record 173 | kamenskoye
# City not found. Skipping...
# Processing Record 174 | sulangan
# Processing Record 175 | taltal
# Processing Record 176 | buala
# Processing Record 177 | inverell
# Processing Record 178 | spirit river
# Processing Record 179 | lienz
# Processing Record 180 | clyde river
# Processing Record 181 | jamestown
# Processing Record 182 | tabou
# Processing Record 183 | barrow
# Processing Record 184 | ayagoz
# Processing Record 185 | areosa
# Processing Record 186 | ribeira grande
# Processing Record 187 | poum
# Processing Record 188 | mnogovershinnyy
# Processing Record 189 | tasbuget
# City not found. Skipping...
# Processing Record 190 | chilca
# Processing Record 191 | tabiauea
# City not found. Skipping...
# Processing Record 192 | redlands
# Processing Record 193 | alpena
# Processing Record 194 | domoni
# Processing Record 195 | kaoma
# Processing Record 196 | tsentralnyy
# City not found. Skipping...
# Processing Record 197 | saint anthony
# Processing Record 198 | azimur
# City not found. Skipping...
# Processing Record 199 | yerbogachen
# Processing Record 200 | vaini
# Processing Record 201 | grand river south east
# City not found. Skipping...
# Processing Record 202 | dangriga
# Processing Record 203 | ponta do sol
# Processing Record 204 | saint-philippe
# Processing Record 205 | port said
# Processing Record 206 | zolotinka
# City not found. Skipping...
# Processing Record 207 | borba
# Processing Record 208 | celestun
# Processing Record 209 | olafsvik
# Processing Record 210 | saskylakh
# Processing Record 211 | tsihombe
# City not found. Skipping...
# Processing Record 212 | pisco
# Processing Record 213 | baghdad
# Processing Record 214 | eskasem
# City not found. Skipping...
# Processing Record 215 | bengkulu
# Processing Record 216 | mayor pablo lagerenza
# Processing Record 217 | butaritari
# Processing Record 218 | jumla
# Processing Record 219 | pitimbu
# Processing Record 220 | terrace
# Processing Record 221 | abu samrah
# Processing Record 222 | yarada
# Processing Record 223 | turayf
# Processing Record 224 | palasbari
# Processing Record 225 | namibe
# Processing Record 226 | urcos
# Processing Record 227 | westpunt
# City not found. Skipping...
# Processing Record 228 | hofn
# Processing Record 229 | kandry
# Processing Record 230 | mar del plata
# Processing Record 231 | chadan
# Processing Record 232 | paita
# Processing Record 233 | villamontes
# Processing Record 234 | tunduru
# City not found. Skipping...
# Processing Record 235 | geraldton
# Processing Record 236 | maniwaki
# Processing Record 237 | victoria
# Processing Record 238 | nador
# Processing Record 239 | shelburne
# Processing Record 240 | new norfolk
# Processing Record 241 | cabo san lucas
# Processing Record 242 | guiglo
# Processing Record 243 | talcahuano
# Processing Record 244 | bergerac
# Processing Record 245 | belmopan
# Processing Record 246 | qaanaaq
# Processing Record 247 | valle de allende
# Processing Record 248 | dingle
# Processing Record 249 | bandundu
# Processing Record 250 | avarua
# Processing Record 251 | cherskiy
# Processing Record 252 | clovis
# Processing Record 253 | esfahan
# Processing Record 254 | mahebourg
# Processing Record 255 | bose
# Processing Record 256 | fairbanks
# Processing Record 257 | burgeo
# Processing Record 258 | linxia
# Processing Record 259 | san lawrenz
# Processing Record 260 | balakhninskiy
# Processing Record 261 | egvekinot
# Processing Record 262 | mahon
# Processing Record 263 | bethel
# Processing Record 264 | derzhavinsk
# Processing Record 265 | vaitupu
# City not found. Skipping...
# Processing Record 266 | wahran
# City not found. Skipping...
# Processing Record 267 | norman wells
# Processing Record 268 | dengzhou
# Processing Record 269 | yellowknife
# Processing Record 270 | barentsburg
# City not found. Skipping...
# Processing Record 271 | fort nelson
# Processing Record 272 | olga
# Processing Record 273 | tahta
# Processing Record 274 | mogapi
# Processing Record 275 | kenora
# Processing Record 276 | torbay
# Processing Record 277 | rosetta
# Processing Record 278 | barra velha
# Processing Record 279 | agua verde
# Processing Record 280 | maridi
# Processing Record 281 | lerwick
# Processing Record 282 | colon
# Processing Record 283 | kumluca
# Processing Record 284 | airai
# Processing Record 285 | la tuque
# Processing Record 286 | sechura
# Processing Record 287 | kodiak
# Processing Record 288 | ouesso
# Processing Record 289 | moron
# Processing Record 290 | narsaq
# Processing Record 291 | yeppoon
# Processing Record 292 | lompoc
# Processing Record 293 | saint-leu
# Processing Record 294 | la libertad
# Processing Record 295 | laguna
# Processing Record 296 | yumen
# Processing Record 297 | mankera
# Processing Record 298 | tynda
# Processing Record 299 | salinopolis
# Processing Record 300 | luderitz
# Processing Record 301 | los llanos de aridane
# Processing Record 302 | pochutla
# Processing Record 303 | nanyang
# Processing Record 304 | lasa
# Processing Record 305 | shingu
# Processing Record 306 | barguzin
# Processing Record 307 | tsabong
# Processing Record 308 | solnechnyy
# Processing Record 309 | margate
# Processing Record 310 | chumikan
# Processing Record 311 | leningradskiy
# Processing Record 312 | hokitika
# Processing Record 313 | huarmey
# Processing Record 314 | beringovskiy
# Processing Record 315 | alice springs
# Processing Record 316 | wanning
# Processing Record 317 | chalchihuites
# Processing Record 318 | rio gallegos
# Processing Record 319 | chokwe
# Processing Record 320 | huambo
# Processing Record 321 | herat
# Processing Record 322 | mount isa
# Processing Record 323 | erenhot
# Processing Record 324 | codrington
# Processing Record 325 | shush
# Processing Record 326 | husavik
# Processing Record 327 | port keats
# Processing Record 328 | amderma
# City not found. Skipping...
# Processing Record 329 | yar-sale
# Processing Record 330 | roald
# Processing Record 331 | sorkjosen
# Processing Record 332 | tucuman
# Processing Record 333 | korla
# Processing Record 334 | saint-joseph
# Processing Record 335 | sultepec
# Processing Record 336 | boyolangu
# Processing Record 337 | dossor
# Processing Record 338 | ancud
# Processing Record 339 | umm durman
# City not found. Skipping...
# Processing Record 340 | yambio
# Processing Record 341 | puerto colombia
# Processing Record 342 | ulaanbaatar
# Processing Record 343 | kytlym
# City not found. Skipping...
# Processing Record 344 | atherton
# Processing Record 345 | staryy krym
# Processing Record 346 | bogorodskoye
# Processing Record 347 | hailun
# Processing Record 348 | fortuna
# Processing Record 349 | povenets
# Processing Record 350 | dobric
# Processing Record 351 | bolobo
# Processing Record 352 | nome
# Processing Record 353 | benjamin constant
# Processing Record 354 | bonavista
# Processing Record 355 | bilma
# Processing Record 356 | bensonville
# Processing Record 357 | mardin
# Processing Record 358 | luau
# Processing Record 359 | saint-augustin
# Processing Record 360 | shakiso
# Processing Record 361 | afanasyevo
# City not found. Skipping...
# Processing Record 362 | marawi
# Processing Record 363 | caravelas
# Processing Record 364 | bambous virieux
# Processing Record 365 | faanui
# Processing Record 366 | vila franca do campo
# Processing Record 367 | hirara
# Processing Record 368 | esmeraldas
# Processing Record 369 | muri
# Processing Record 370 | mildura
# Processing Record 371 | ilebo
# Processing Record 372 | hami
# Processing Record 373 | chimbote
# Processing Record 374 | zaraza
# Processing Record 375 | hambantota
# Processing Record 376 | mahibadhoo
# Processing Record 377 | svatove
# Processing Record 378 | zhigansk
# Processing Record 379 | reforma
# Processing Record 380 | college
# Processing Record 381 | malangwa
# Processing Record 382 | havoysund
# Processing Record 383 | colesberg
# Processing Record 384 | san jose
# Processing Record 385 | guabito
# Processing Record 386 | karamay
# City not found. Skipping...
# Processing Record 387 | thinadhoo
# Processing Record 388 | astara
# Processing Record 389 | hasaki
# Processing Record 390 | constitucion
# Processing Record 391 | mufulira
# Processing Record 392 | dongying
# Processing Record 393 | srednekolymsk
# Processing Record 394 | biak
# Processing Record 395 | ahipara
# Processing Record 396 | qingan
# City not found. Skipping...
# Processing Record 397 | san ramon
# Processing Record 398 | high prairie
# Processing Record 399 | takoradi
# Processing Record 400 | khani
# Processing Record 401 | avera
# Processing Record 402 | ewa beach
# Processing Record 403 | luang prabang
# Processing Record 404 | santa rosalia
# Processing Record 405 | xifeng
# Processing Record 406 | mehamn
# Processing Record 407 | pedernales
# Processing Record 408 | gulshat
# City not found. Skipping...
# Processing Record 409 | balykshi
# City not found. Skipping...
# Processing Record 410 | klaksvik
# Processing Record 411 | saint george
# Processing Record 412 | bathsheba
# Processing Record 413 | sanmenxia
# Processing Record 414 | kita
# Processing Record 415 | portobelo
# Processing Record 416 | byron bay
# Processing Record 417 | businga
# Processing Record 418 | kivsharivka
# Processing Record 419 | mutsu
# Processing Record 420 | tangwani
# Processing Record 421 | wamba
# Processing Record 422 | sept-iles
# Processing Record 423 | loralai
# Processing Record 424 | krasnogorskoye
# Processing Record 425 | vao
# Processing Record 426 | nizhneyansk
# City not found. Skipping...
# Processing Record 427 | nurota
# Processing Record 428 | atambua
# Processing Record 429 | palabuhanratu
# City not found. Skipping...
# Processing Record 430 | doha
# Processing Record 431 | souillac
# Processing Record 432 | northam
# Processing Record 433 | rafai
# Processing Record 434 | cozumel
# Processing Record 435 | attawapiskat
# City not found. Skipping...
# Processing Record 436 | kudahuvadhoo
# Processing Record 437 | panzhihua
# Processing Record 438 | cockburn town
# Processing Record 439 | henties bay
# Processing Record 440 | foso
# Processing Record 441 | khawhai
# Processing Record 442 | feijo
# Processing Record 443 | nguiu
# City not found. Skipping...
# Processing Record 444 | cheuskiny
# City not found. Skipping...
# Processing Record 445 | fairview
# Processing Record 446 | horodnya
# Processing Record 447 | gornoye loo
# Processing Record 448 | coihaique
# Processing Record 449 | lesozavodsk
# Processing Record 450 | ilhabela
# Processing Record 451 | botwood
# Processing Record 452 | brae
# Processing Record 453 | viedma
# Processing Record 454 | kloulklubed
# Processing Record 455 | verkhnyaya sinyachikha
# Processing Record 456 | barranca
# Processing Record 457 | grants pass
# Processing Record 458 | grand gaube
# Processing Record 459 | zhuhai
# Processing Record 460 | longyearbyen
# Processing Record 461 | pilar
# Processing Record 462 | port-gentil
# Processing Record 463 | sousa
# Processing Record 464 | catarama
# Processing Record 465 | lavrentiya
# Processing Record 466 | forbes
# Processing Record 467 | gimli
# Processing Record 468 | akhmim
# Processing Record 469 | charagua
# Processing Record 470 | cherlak
# Processing Record 471 | berlevag
# Processing Record 472 | yeletskiy
# City not found. Skipping...
# Processing Record 473 | vanimo
# Processing Record 474 | aguascalientes
# Processing Record 475 | khandyga
# Processing Record 476 | toppenish
# Processing Record 477 | taoudenni
# Processing Record 478 | north branch
# Processing Record 479 | mrirt
# City not found. Skipping...
# Processing Record 480 | izumo
# Processing Record 481 | maniitsoq
# Processing Record 482 | vrangel
# Processing Record 483 | kijang
# Processing Record 484 | vanavara
# Processing Record 485 | isangel
# Processing Record 486 | channel-port aux basques
# Processing Record 487 | makakilo city
# Processing Record 488 | mandera
# Processing Record 489 | bur gabo
# City not found. Skipping...
# Processing Record 490 | west islip
# Processing Record 491 | loukhi
# Processing Record 492 | ca mau
# Processing Record 493 | oxapampa
# Processing Record 494 | umba
# Processing Record 495 | bocaranga
# City not found. Skipping...
# Processing Record 496 | goderich
# Processing Record 497 | leshukonskoye
# Processing Record 498 | faya
# Processing Record 499 | olavarria
# Processing Record 500 | novyy urengoy
# Processing Record 501 | hualmay
# Processing Record 502 | pacsa
# Processing Record 503 | mocambique
# City not found. Skipping...
# Processing Record 504 | dhidhdhoo
# Processing Record 505 | gimbi
# Processing Record 506 | bontang
# Processing Record 507 | camana
# Processing Record 508 | turan
# Processing Record 509 | yelbarga
# Processing Record 510 | maracaibo
# Processing Record 511 | mugur-aksy
# Processing Record 512 | yorosso
# Processing Record 513 | dakar
# Processing Record 514 | rio grande
# Processing Record 515 | jutai
# Processing Record 516 | kracheh
# City not found. Skipping...
# Processing Record 517 | tessalit
# Processing Record 518 | baculin
# Processing Record 519 | manosque
# Processing Record 520 | doos
# Processing Record 521 | muisne
# Processing Record 522 | dunmore town
# Processing Record 523 | ambodifototra
# City not found. Skipping...
# Processing Record 524 | iquique
# Processing Record 525 | ozinki
# Processing Record 526 | oistins
# Processing Record 527 | rock sound
# Processing Record 528 | quesnel
# Processing Record 529 | adrar
# Processing Record 530 | along
# Processing Record 531 | dudinka
# Processing Record 532 | nouadhibou
# Processing Record 533 | kutum
# Processing Record 534 | nouakchott
# Processing Record 535 | gland
# Processing Record 536 | nioaque
# Processing Record 537 | port hedland
# Processing Record 538 | palana
# Processing Record 539 | usinsk
# Processing Record 540 | burica
# City not found. Skipping...
# Processing Record 541 | santa isabel do rio negro
# Processing Record 542 | quelimane
# Processing Record 543 | chernyshevsk
# Processing Record 544 | beyneu
# Processing Record 545 | petropavlovsk-kamchatskiy
# Processing Record 546 | racoasa
# Processing Record 547 | fort saint james
# Processing Record 548 | richards bay
# Processing Record 549 | ketchikan
# Processing Record 550 | mangai
# Processing Record 551 | north bend
# Processing Record 552 | shahr-e kord
# Processing Record 553 | sur
# Processing Record 554 | vila velha
# Processing Record 555 | tuensang
# Processing Record 556 | flinders
# Processing Record 557 | port hardy
# Processing Record 558 | san carlos de bariloche
# Processing Record 559 | muros
# Processing Record 560 | imeni poliny osipenko
# Processing Record 561 | sumbe
# Processing Record 562 | tateyama
# Processing Record 563 | pangkalanbuun
# Processing Record 564 | kaitangata
# Processing Record 565 | okhotsk
# Processing Record 566 | rapid valley
# Processing Record 567 | flin flon
# Processing Record 568 | ibra
# Processing Record 569 | te anau
# Processing Record 570 | matara
# Processing Record 571 | zyryanka
# Processing Record 572 | trincomalee
# Processing Record 573 | manokwari
# Processing Record 574 | yakeshi
# Processing Record 575 | iqaluit
# Processing Record 576 | camopi
# Processing Record 577 | phek
# Processing Record 578 | khorramabad
# Processing Record 579 | lagunas
# Processing Record 580 | maragogi
# Processing Record 581 | palu
# Processing Record 582 | pacific grove
# Processing Record 583 | nuuk
# Processing Record 584 | eucaliptus
# Processing Record 585 | rey bouba
# Processing Record 586 | buchanan
# Processing Record 587 | cayenne
# Processing Record 588 | kerema
# Processing Record 589 | iralaya
# Processing Record 590 | ayutinskiy
# Processing Record 591 | mentok
# City not found. Skipping...
# Processing Record 592 | assiniboia
# Processing Record 593 | monrovia
# Processing Record 594 | gold coast
# Processing Record 595 | sistranda
# Processing Record 596 | ryotsu
# Processing Record 597 | at-bashi
# Processing Record 598 | makoshyne
# Processing Record 599 | tangara
# Processing Record 600 | karmala
# Processing Record 601 | bowen
# Processing Record 602 | huanren
# Processing Record 603 | kegayli
# City not found. Skipping...
# Processing Record 604 | mabaruma
# Processing Record 605 | russell
# Processing Record 606 | toccoa
# Processing Record 607 | jaca
# Processing Record 608 | braslav
# City not found. Skipping...
# Processing Record 609 | moyo
# Processing Record 610 | ruatoria
# City not found. Skipping...
# Processing Record 611 | naifaru
# Processing Record 612 | san rafael
# Processing Record 613 | sile
# Processing Record 614 | majene
# Processing Record 615 | samarai
# Processing Record 616 | hammerfest
# Processing Record 617 | dwarka
# Processing Record 618 | sampit
# Processing Record 619 | rafaela
# Processing Record 620 | suluq
# Processing Record 621 | hyeres
# Processing Record 622 | russkaya polyana
# Processing Record 623 | mitsamiouli
# Processing Record 624 | canico
# Processing Record 625 | moose factory
# Processing Record 626 | diamantino
# Processing Record 627 | nisia floresta
# Processing Record 628 | mananjary
# Processing Record 629 | umzimvubu
# City not found. Skipping...
# Processing Record 630 | baruun-urt
# Processing Record 631 | katsuura
# Processing Record 632 | mayumba
# Processing Record 633 | puri
# Processing Record 634 | nola
# Processing Record 635 | vallenar
# Processing Record 636 | isla mujeres
# Processing Record 637 | marcona
# City not found. Skipping...
# Processing Record 638 | aripuana
# Processing Record 639 | havelock

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Creating a data frame with the weather data from API call
weather_data_df = pd.DataFrame({'City': city_name,
                              'Country': country,
                               'Latitude': lat,
                               'Longitude': lng,
                               'Max Temp': max_temp,
                               'Humidity': humidity,
                               'Cloudiness': cloudiness,
                               'Wind Speed': wind_speed,
                               'Date': weather_date})

# Export file as a CSV, without the Pandas index, but with the header
weather_data_df.to_csv("Output/Weather_Data.csv", index=False, header=True)

weather_data_df.count()
# Out:
# City          581
# Country       581
# Latitude      581
# Longitude     581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Date          581
# dtype: int64

# %%
weather_data_df
# Out:
#              City Country  Latitude  Longitude  Max Temp  Humidity  \
# 0          Helong      CN     42.54     129.00     27.96        52
# 1           Bluff      NZ    -46.60     168.33      7.68        75
# 2       Busselton      AU    -33.65     115.33     18.33        80
# 3       Kathmandu      NP     27.72      85.32     23.00        94
# 4      Kefamenanu      ID     -9.45     124.48     24.96        64
# ..            ...     ...       ...        ...       ...       ...
# 576          Nola      IT     40.92      14.53     21.00        77
# 577      Vallenar      CL    -28.57     -70.76     14.47        51
# 578  Isla Mujeres      MX     21.23     -86.73     29.00        89
# 579      Aripuanã      BR     -9.17     -60.63     22.75        52
# 580      Havelock      US     34.88     -76.90     26.67        80
#
#      Cloudiness  Wind Speed      Date
# 0             1        1.58  07/15/20
# 1            20        6.07  07/15/20
# 2            10       10.22  07/15/20
# 3            75        0.62  07/15/20
# 4            24        4.14  07/15/20
# ..          ...         ...       ...
# 576          20        0.51  07/15/20
# 577           0        0.54  07/15/20
# 578          40        2.10  07/15/20
# 579           0        0.79  07/15/20
# 580           1        2.10  07/15/20
#
# [581 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Checking what the max humidity is
weather_data_df['Humidity'].max()

# Since no cities have humidity > 100, weather_data is a clean data set and this section is not needed
# Out:
# 100

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame

# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create scatter plot of weight and mean tumor volume with configuration
weather_date = weather_data_df['Date'][0]

plt.scatter(
    weather_data_df['Latitude'], 
    weather_data_df['Max Temp'],
    marker="o",  
    edgecolors="black")

plt.title(f'City Latitude vs. Temperature {weather_date}')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)

plt.savefig('Figures/Latitude Vs Temperature.png')
plt.show()

# %% [markdown]
# In this analysis of latitude of a city compared to its temperature we see that the closer the city is to the equater (latitude = 0), the higher the max temperature will be.
# What is interesting to note, is that at a latitude of 30<sup>o</sup> the max temperature is the highest. This could be due to the angle at which Earth orbits the Sun.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create scatter plot of weight and mean tumor volume with configuration
plt.scatter(
    weather_data_df['Latitude'], 
    weather_data_df['Humidity'],
    marker="o",  
    edgecolors="black")

plt.title(f'City Latitude vs. Humidity {weather_date}')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

plt.savefig('Figures/Latitude Vs Humidity.png')
plt.show()

# %% [markdown]
# There does not seem to be a strong correlation between the latitude of a city and its humidity. It does appear that at a latitude of -20<sup>o</sup> and 40<sup>o</sup> the humidity is at its lowest at approximately 15% and 10% respectivel. And for cities at any other latitude, there is a sharp increase in humidity. The majority of cities are at 60% humidity or above.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create scatter plot of weight and mean tumor volume with configuration
plt.scatter(
    weather_data_df['Latitude'], 
    weather_data_df['Cloudiness'],
    marker="o",  
    edgecolors="black")

plt.title(f'City Latitude vs. Cloudiness {weather_date}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

plt.savefig('Figures/Latitude Vs Cloudiness.png')
plt.show()

# %% [markdown]
# There does not seem to be any correlation between the cloudiness of a city and its latitude.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create scatter plot of weight and mean tumor volume with configuration
plt.scatter(
    weather_data_df['Latitude'], 
    weather_data_df['Wind Speed'],
    marker='o',  
    edgecolors='black')

plt.title(f'City Latitude vs. Wind Speed {weather_date}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

plt.savefig('Figures/Latitude Vs Wind Speed.png')
plt.show()

# %% [markdown]
# The correlation between a city's wind speed and its latitude seems to be very week or none at all. As at July 15, 2020 the averge wind speed appears to be between 0 mph and 4 mph.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

def line_regress_plot(x_values, y_values,x_label, y_label, hem, x_ann, y_ann):
    '''Creates a linear regression plot'''
    '''Parameters: x_values = x-axis values, 
                   y_values = x-axis values,
                   x_label, y_label = Axis lables,
                   hem = hemisphere (Northern, Southern)
                   x_ann, y_ann = regression line location'''
    
    # Define date of Weather
    weather_date = weather_data_df['Date'][0]
    #Define file name
    file_name = f'{hem}_Hem {x_label} vs. {y_label}.png'
        
    # Calculate and add linear regression equation to the scatter plot
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    regress_values = x_values * slope + intercept
    line_eqn = f'Y = {str(round(slope,2))}x + {str(round(intercept,2))}'

    plt.scatter(x_values,y_values, edgecolor='black', facecolor='blue', alpha=0.5)
    plt.plot(x_values,regress_values,'r-')
    plt.annotate(line_eqn,(x_ann,y_ann),fontsize=15,color='red')
    plt.title(f'{hem} Hemisphere\nCity {x_label} vs. {y_label} {weather_date}')
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    print(f'The r-squared is: {rvalue**2}')
    print(f'The regression line equation is: {line_eqn}')
    
    plt.savefig(f'Figures/{file_name}')
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hem = weather_data_df.loc[weather_data_df['Latitude'] > 0]
southern_hem = weather_data_df.loc[weather_data_df['Latitude'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
line_regress_plot(northern_hem['Latitude'], northern_hem['Max Temp'],'Latitude', 'Max Temperature (C)', 'Northern', 10, 8)
# Out:
# The r-squared is: 0.44873715210393667
# The regression line equation is: Y = -0.24x + 30.52

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
line_regress_plot(southern_hem['Latitude'], southern_hem['Max Temp'],'Latitude', 'Max Temperature (C)', 'Southern', -55, 25)
# Out:
# The r-squared is: 0.6001993492598998
# The regression line equation is: Y = 0.46x + 26.33

# %% [markdown]
# The linear regression for the northern hemisphere's cities max temperature compared to their latitude is showing that the closer one moves towards the equator (latitude = 0), the higher the max temperature will be.  This is a weak (0.3 <= r <=0.5) negative correlation.
#
# The linear regression for the southern hemispheres cities max temperatures compared to their ladtitudes however, produces a strong positive correlation (0.5 <= r <= 0.7) for when the latitude approaches the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
line_regress_plot(northern_hem['Latitude'], northern_hem['Humidity'],'Latitude', 'Humidity (%)', 'Northern', 48, 10)
# Out:
# The r-squared is: 0.0022779076729396866
# The regression line equation is: Y = -0.05x + 73.09

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
line_regress_plot(southern_hem['Latitude'], southern_hem['Humidity'],'Latitude', 'Humidity (%)', 'Southern', -55, 20)
# Out:
# The r-squared is: 0.007120832463229182
# The regression line equation is: Y = 0.11x + 74.23

# %% [markdown]
# As expected, the linear regression for both the northern and southern hemispheres for humidity campared to the latitude are not correlated or have a very weak correlation (r < 0.3). Based on this, we can say that the latitue of a city does not have an effect on its humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
line_regress_plot(northern_hem['Latitude'], northern_hem['Cloudiness'],'Latitude', 'Cloudiness (%)', 'Northern', 47, 62)
# Out:
# The r-squared is: 2.833843672617629e-05
# The regression line equation is: Y = -0.01x + 53.91

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
line_regress_plot(southern_hem['Latitude'], southern_hem['Cloudiness'],'Latitude', 'Cloudiness (%)', 'Southern', -55, 40)
# Out:
# The r-squared is: 0.015613838200399402
# The regression line equation is: Y = 0.35x + 49.45

# %% [markdown]
# While the linear regression for the northern hemispheres cloudiness campared to the temperature is not correlated or has a very weak correlation (r < 0.3), (r = 0.00000283), the correlation for the southern hemispheres data is slightly stronger, even though it is still a weak correlation (r = 0.0156). Based on this, we can say that the latitue of a city does not have an effect on its humidity.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
line_regress_plot(northern_hem['Latitude'], northern_hem['Wind Speed'],'Latitude', 'Wind Speed (mph)', 'Northern', 15, 10)
# Out:
# The r-squared is: 0.005537832377359313
# The regression line equation is: Y = 0.01x + 3.05

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
line_regress_plot(southern_hem['Latitude'], southern_hem['Wind Speed'],'Latitude', 'Wind Speed (mph)', 'Southern', -50, 10)
# Out:
# The r-squared is: 2.3747637176469173e-06
# The regression line equation is: Y = -0.0x + 3.14

# %% [markdown]
# The linear regression for both the northern and southern hemispheres for wind speed campared to the latitude are not correlated or have a very weak correlation (r < 0.3). Based on this, we can say that the latitue of a city does not have an effect on its wind speed.
