# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build base url
base_url = 'http://api.openweathermap.org/data/2.5/weather?&units=metric'
# query url
query_url = f'{base_url}&appid={weather_api_key}&q='

# Counters
set_counter = 1

city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
weather_date = []

print ('Beginning Data Retrieval')
print ('------------------------')

# Creating a loop to make api calls for each city in our list
for i, city in enumerate (cities):
    
    # Keeping a counter of sets of data
    if set_counter == 50:
        set_counter = 1
    
    response = requests.get(query_url+city).json()
    print (f'Processing Record {i} of Set {set_counter} | {city}')
    
    # Try to get the data from API, if no data or city is available, skip that city and continue
    try:
        # retrieve and append lists with data
        city_name.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        weather_date.append((datetime.fromtimestamp(response['dt'])).strftime('%m/%d/%y'))
        
        set_counter += 1
        
    # Handle all exceptions for a city that is not available in the Weather API by passing over it
    except:
        print ('City not found. Skipping...')
        pass
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 0 of Set 1 | barrow
# Processing Record 1 of Set 2 | coihaique
# Processing Record 2 of Set 3 | mataura
# Processing Record 3 of Set 4 | sao filipe
# Processing Record 4 of Set 5 | hobart
# Processing Record 5 of Set 6 | buraydah
# Processing Record 6 of Set 7 | ambon
# Processing Record 7 of Set 8 | trinidad
# Processing Record 8 of Set 9 | bluff
# Processing Record 9 of Set 10 | kasama
# Processing Record 10 of Set 11 | itarema
# Processing Record 11 of Set 12 | saint george
# Processing Record 12 of Set 13 | provideniya
# Processing Record 13 of Set 14 | gurupa
# Processing Record 14 of Set 15 | jamestown
# Processing Record 15 of Set 16 | urdoma
# Processing Record 16 of Set 17 | half moon bay
# Processing Record 17 of Set 18 | port alfred
# Processing Record 18 of Set 19 | dingle
# Processing Record 19 of Set 20 | bredasdorp
# Processing Record 20 of Set 21 | samarai
# Processing Record 21 of Set 22 | ushuaia
# Processing Record 22 of Set 23 | bambous virieux
# Processing Record 23 of Set 24 | busselton
# Processing Record 24 of Set 25 | caravelas
# Processing Record 25 of Set 26 | puerto ayora
# Processing Record 26 of Set 27 | wilmington
# Processing Record 27 of Set 28 | hofn
# Processing Record 28 of Set 29 | hithadhoo
# Processing Record 29 of Set 30 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 30 | san patricio
# Processing Record 31 of Set 31 | butaritari
# Processing Record 32 of Set 32 | villazon
# Processing Record 33 of Set 33 | totma
# Processing Record 34 of Set 34 | north bend
# Processing Record 35 of Set 35 | albany
# Processing Record 36 of Set 36 | aktash
# Processing Record 37 of Set 37 | tongren
# Processing Record 38 of Set 38 | rikitea
# Processing Record 39 of Set 39 | cape town
# Processing Record 40 of Set 40 | hasaki
# Processing Record 41 of Set 41 | grand-lahou
# Processing Record 42 of Set 42 | puerto ayacucho
# Processing Record 43 of Set 43 | pevek
# Processing Record 44 of Set 44 | coahuayana
# Processing Record 45 of Set 45 | hauterive
# Processing Record 46 of Set 46 | roma
# Processing Record 47 of Set 47 | cap malheureux
# Processing Record 48 of Set 48 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 48 | igarka
# Processing Record 50 of Set 49 | parras
# City not found. Skipping...
# Processing Record 51 of Set 49 | trelew
# Processing Record 52 of Set 50 | punta arenas
# Processing Record 53 of Set 51 | amderma
# City not found. Skipping...
# Processing Record 54 of Set 51 | arica
# Processing Record 55 of Set 52 | warri
# Processing Record 56 of Set 53 | havre-saint-pierre
# Processing Record 57 of Set 54 | hermanus
# Processing Record 58 of Set 55 | mar del plata
# Processing Record 59 of Set 56 | esperance
# Processing Record 60 of Set 57 | norman wells
# Processing Record 61 of Set 58 | kapaa
# Processing Record 62 of Set 59 | yellowknife
# Processing Record 63 of Set 60 | port elizabeth
# Processing Record 64 of Set 61 | besikduzu
# Processing Record 65 of Set 62 | georgiyevka
# Processing Record 66 of Set 63 | havoysund
# Processing Record 67 of Set 64 | east london
# Processing Record 68 of Set 65 | hilo
# Processing Record 69 of Set 66 | pyapon
# Processing Record 70 of Set 67 | sitka
# Processing Record 71 of Set 68 | karaul
# City not found. Skipping...
# Processing Record 72 of Set 68 | prachuap khiri khan
# Processing Record 73 of Set 69 | leningradskiy
# Processing Record 74 of Set 70 | kokopo
# Processing Record 75 of Set 71 | turukhansk
# Processing Record 76 of Set 72 | ahipara
# Processing Record 77 of Set 73 | port blair
# Processing Record 78 of Set 74 | oranjemund
# Processing Record 79 of Set 75 | saint-philippe
# Processing Record 80 of Set 76 | sinnamary
# Processing Record 81 of Set 77 | poum
# Processing Record 82 of Set 78 | zhigansk
# Processing Record 83 of Set 79 | carnarvon
# Processing Record 84 of Set 80 | magadan
# Processing Record 85 of Set 81 | lolua
# City not found. Skipping...
# Processing Record 86 of Set 81 | arlit
# Processing Record 87 of Set 82 | sydney
# Processing Record 88 of Set 83 | grand river south east
# City not found. Skipping...
# Processing Record 89 of Set 83 | hannibal
# Processing Record 90 of Set 84 | carpentras
# Processing Record 91 of Set 85 | beringovskiy
# Processing Record 92 of Set 86 | khatanga
# Processing Record 93 of Set 87 | kaitangata
# Processing Record 94 of Set 88 | roberval
# Processing Record 95 of Set 89 | rock sound
# Processing Record 96 of Set 90 | pergamino
# Processing Record 97 of Set 91 | lebanon
# Processing Record 98 of Set 92 | castro
# Processing Record 99 of Set 93 | agustin codazzi
# Processing Record 100 of Set 94 | ilulissat
# Processing Record 101 of Set 95 | upernavik
# Processing Record 102 of Set 96 | celestun
# Processing Record 103 of Set 97 | narsaq
# Processing Record 104 of Set 98 | xichang
# Processing Record 105 of Set 99 | vardo
# Processing Record 106 of Set 100 | yar-sale
# Processing Record 107 of Set 101 | tangshan
# Processing Record 108 of Set 102 | faanui
# Processing Record 109 of Set 103 | tessalit
# Processing Record 110 of Set 104 | nanortalik
# Processing Record 111 of Set 105 | severo-kurilsk
# Processing Record 112 of Set 106 | sola
# Processing Record 113 of Set 107 | guerrero negro
# Processing Record 114 of Set 108 | tasiilaq
# Processing Record 115 of Set 109 | thompson
# Processing Record 116 of Set 110 | leh
# Processing Record 117 of Set 111 | saskylakh
# Processing Record 118 of Set 112 | bethel
# Processing Record 119 of Set 113 | port keats
# Processing Record 120 of Set 114 | dikson
# Processing Record 121 of Set 115 | new norfolk
# Processing Record 122 of Set 116 | rockingham
# Processing Record 123 of Set 117 | igrim
# Processing Record 124 of Set 118 | siva
# Processing Record 125 of Set 119 | araouane
# Processing Record 126 of Set 120 | ponta do sol
# Processing Record 127 of Set 121 | guiglo
# Processing Record 411 of Set 380 | mahibadhoo
# Processing Record 412 of Set 381 | yerbogachen
# Processing Record 413 of Set 382 | nagato
# Processing Record 414 of Set 383 | guapore
# Processing Record 415 of Set 384 | srostki
# Processing Record 416 of Set 385 | pingzhuang
# Processing Record 417 of Set 386 | vostok
# Processing Record 418 of Set 387 | sulangan
# Processing Record 419 of Set 388 | lake havasu city
# Processing Record 420 of Set 389 | mutsamudu
# City not found. Skipping...
# Processing Record 421 of Set 389 | sinegorye
# Processing Record 422 of Set 390 | chicama
# Processing Record 423 of Set 391 | yulara
# Processing Record 424 of Set 392 | madawaska
# Processing Record 425 of Set 393 | chota
# Processing Record 426 of Set 394 | santa maria
# Processing Record 427 of Set 395 | pouebo
# Processing Record 428 of Set 396 | pijijiapan
# Processing Record 429 of Set 397 | coolum beach
# Processing Record 430 of Set 398 | nador
# Processing Record 431 of Set 399 | san ramon
# Processing Record 432 of Set 400 | tecoanapa
# Processing Record 433 of Set 401 | springdale
# Processing Record 434 of Set 402 | chapais
# Processing Record 435 of Set 403 | show low
# Processing Record 436 of Set 404 | imbituba
# Processing Record 437 of Set 405 | rorvik
# Processing Record 438 of Set 406 | marsabit
# Processing Record 439 of Set 407 | saryshagan
# City not found. Skipping...
# Processing Record 440 of Set 407 | hong gai
# Processing Record 441 of Set 408 | bernau
# Processing Record 442 of Set 409 | nanning
# Processing Record 443 of Set 410 | iqaluit
# Processing Record 444 of Set 411 | ahuimanu
# Processing Record 445 of Set 412 | yumen
# Processing Record 446 of Set 413 | umm jarr
# City not found. Skipping...
# Processing Record 447 of Set 413 | kapuskasing
# Processing Record 448 of Set 414 | nikolskoye
# Processing Record 449 of Set 415 | axim
# Processing Record 450 of Set 416 | kamenskoye
# City not found. Skipping...
# Processing Record 451 of Set 416 | sao joao da barra
# Processing Record 452 of Set 417 | abut
# Processing Record 453 of Set 418 | fukue
# Processing Record 454 of Set 419 | yashalta
# Processing Record 455 of Set 420 | qeshm
# Processing Record 456 of Set 421 | la plata
# Processing Record 457 of Set 422 | acapetahua
# Processing Record 458 of Set 423 | bandarbeyla
# Processing Record 459 of Set 424 | tambacounda
# Processing Record 460 of Set 425 | hokitika
# Processing Record 461 of Set 426 | borogontsy
# Processing Record 462 of Set 427 | mage
# Processing Record 463 of Set 428 | mala
# Processing Record 464 of Set 429 | grants
# Processing Record 465 of Set 430 | katsuura
# Processing Record 466 of Set 431 | ijaki
# City not found. Skipping...
# Processing Record 467 of Set 431 | blagoyevo
# Processing Record 468 of Set 432 | uyemskiy
# Processing Record 469 of Set 433 | coquimbo
# Processing Record 470 of Set 434 | biltine
# Processing Record 471 of Set 435 | nhulunbuy
# Processing Record 472 of Set 436 | puerto del rosario
# Processing Record 473 of Set 437 | motema
# Processing Record 474 of Set 438 | ribeira grande
# Processing Record 475 of Set 439 | nouadhibou
# Processing Record 476 of Set 440 | vila
# Processing Record 477 of Set 441 | eyl
# Processing Record 478 of Set 442 | talaya
# Processing Record 479 of Set 443 | liberia
# Processing Record 480 of Set 444 | hami
# Processing Record 481 of Set 445 | umzimvubu
# City not found. Skipping...
# Processing Record 482 of Set 445 | victoria
# Processing Record 483 of Set 446 | brae
# Processing Record 484 of Set 447 | tutoia
# Processing Record 485 of Set 448 | sosnovo-ozerskoye
# Processing Record 486 of Set 449 | egvekinot
# Processing Record 487 of Set 450 | pitimbu
# Processing Record 488 of Set 451 | jalu
# Processing Record 489 of Set 452 | ambilobe
# Processing Record 490 of Set 453 | mortka
# Processing Record 491 of Set 454 | veraval
# Processing Record 492 of Set 455 | cherkasskoye
# Processing Record 493 of Set 456 | binzhou
# Processing Record 494 of Set 457 | tautira
# Processing Record 495 of Set 458 | college
# Processing Record 496 of Set 459 | malanje
# Processing Record 497 of Set 460 | emerald
# Processing Record 498 of Set 461 | namatanai
# Processing Record 499 of Set 462 | folkestone
# Processing Record 500 of Set 463 | parfino
# Processing Record 501 of Set 464 | fare
# Processing Record 502 of Set 465 | pangody
# Processing Record 503 of Set 466 | jadu
# Processing Record 504 of Set 467 | olinda
# Processing Record 505 of Set 468 | innisfail
# Processing Record 506 of Set 469 | lata
# Processing Record 507 of Set 470 | san policarpo
# Processing Record 508 of Set 471 | vallenar
# Processing Record 509 of Set 472 | mananara
# Processing Record 510 of Set 473 | tapaua
# City not found. Skipping...
# Processing Record 511 of Set 473 | bubaque
# Processing Record 512 of Set 474 | atyrau
# Processing Record 513 of Set 475 | krasnystaw
# Processing Record 514 of Set 476 | vila do maio
# Processing Record 515 of Set 477 | ornskoldsvik
# Processing Record 516 of Set 478 | vengerovo
# Processing Record 517 of Set 479 | acapulco
# Processing Record 518 of Set 480 | peleduy
# Processing Record 519 of Set 481 | mangan
# Processing Record 520 of Set 482 | kazalinsk
# City not found. Skipping...
# Processing Record 521 of Set 482 | summerside
# Processing Record 522 of Set 483 | kirakira
# Processing Record 523 of Set 484 | turmalina
# Processing Record 524 of Set 485 | birjand
# Processing Record 525 of Set 486 | ardistan
# City not found. Skipping...
# Processing Record 526 of Set 486 | sao felix do xingu
# Processing Record 527 of Set 487 | samaipata
# Processing Record 528 of Set 488 | bur gabo
# City not found. Skipping...
# Processing Record 529 of Set 488 | port-cartier
# Processing Record 530 of Set 489 | lock haven
# Processing Record 531 of Set 490 | huamachuco
# Processing Record 532 of Set 491 | wulanhaote
# City not found. Skipping...
# Processing Record 533 of Set 491 | port hueneme
# Processing Record 534 of Set 492 | kavieng
# Processing Record 535 of Set 493 | merauke
# Processing Record 536 of Set 494 | hambantota
# Processing Record 537 of Set 495 | ryotsu
# Processing Record 538 of Set 496 | limon
# Processing Record 539 of Set 497 | karuri
# Processing Record 540 of Set 498 | komoro
# Processing Record 541 of Set 499 | haukipudas
# Processing Record 542 of Set 500 | loukhi
# Processing Record 543 of Set 501 | baracatan
# Processing Record 544 of Set 502 | lastoursville
# Processing Record 545 of Set 503 | cove
# Processing Record 546 of Set 504 | beyneu
# Processing Record 547 of Set 505 | lukulu
# Processing Record 548 of Set 506 | constitucion
# Processing Record 549 of Set 507 | trabzon
# Processing Record 550 of Set 508 | walvis bay
# Processing Record 551 of Set 509 | antofagasta
# Processing Record 552 of Set 510 | ust-kuyga
# Processing Record 553 of Set 511 | daru
# Processing Record 554 of Set 512 | riyadh
# Processing Record 555 of Set 513 | emba
# Processing Record 556 of Set 514 | karkaralinsk
# City not found. Skipping...
# Processing Record 557 of Set 514 | morgan city
# Processing Record 558 of Set 515 | eufaula
# Processing Record 559 of Set 516 | grindavik
# Processing Record 560 of Set 517 | vanderhoof
# Processing Record 561 of Set 518 | cabinda
# Processing Record 562 of Set 519 | norfolk
# Processing Record 563 of Set 520 | sarangani
# Processing Record 564 of Set 521 | kuche
# City not found. Skipping...
# Processing Record 565 of Set 521 | rancho palos verdes
# Processing Record 566 of Set 522 | trairi
# Processing Record 567 of Set 523 | karratha
# Processing Record 568 of Set 524 | liberal
# Processing Record 569 of Set 525 | armidale
# Processing Record 570 of Set 526 | esil
# Processing Record 571 of Set 527 | moindou
# Processing Record 572 of Set 528 | moussoro
# Processing Record 573 of Set 529 | zinder
# Processing Record 574 of Set 530 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 575 of Set 530 | port hardy
# Processing Record 576 of Set 531 | bilibino
# Processing Record 577 of Set 532 | salalah
# Processing Record 578 of Set 533 | sobolevo
# Processing Record 579 of Set 534 | libourne
# Processing Record 580 of Set 535 | kearney
# Processing Record 581 of Set 536 | aksarka
# Processing Record 582 of Set 537 | mega
# Processing Record 583 of Set 538 | rungata
# City not found. Skipping...
# Processing Record 584 of Set 538 | marathon
# Processing Record 585 of Set 539 | lagos
# Processing Record 586 of Set 540 | bellavista
# Processing Record 587 of Set 541 | doha
# Processing Record 588 of Set 542 | ixtapa
# Processing Record 589 of Set 543 | samusu
# City not found. Skipping...
# Processing Record 590 of Set 543 | maceio
# Processing Record 591 of Set 544 | thinadhoo
# Processing Record 592 of Set 545 | amahai
# Processing Record 593 of Set 546 | tarudant
# City not found. Skipping...
# Processing Record 594 of Set 546 | kushiro
# Processing Record 595 of Set 547 | brownsville
# Processing Record 596 of Set 548 | kruisfontein
# Processing Record 597 of Set 549 | madinat sittah uktubar
# Processing Record 598 of Set 550 | diu
# Processing Record 599 of Set 551 | nantucket

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Creating a data frame with the weather data from API call
weather_data_df = pd.DataFrame({'City': city_name,
                              'Country': country,
                               'Latitude': lat,
                               'Longitude': lng,
                               'Max Temp': max_temp,
                               'Humidity': humidity,
                               'Cloudiness': cloudiness,
                               'Wind Speed': wind_speed,
                               'Date': weather_date})

# Export file as a CSV, without the Pandas index, but with the header
weather_data_df.to_csv("Output/Weather_Data.csv", index=False, header=True)

weather_data_df.count()
# Out:
# City          551
# Country       551
# Latitude      551
# Longitude     551
# Max Temp      551
# Humidity      551
# Cloudiness    551
# Wind Speed    551
# Date          551
# dtype: int64

# %%
weather_data_df
# Out:
#                        City Country  Latitude  Longitude  Max Temp  Humidity  \
# 0                    Barrow      US     71.29    -156.79      3.00        86
# 1                 Coyhaique      CL    -45.58     -72.07     -1.00        92
# 2                   Mataura      NZ    -46.19     168.86      3.89        83
# 3                São Filipe      CV     14.90     -24.50     24.57        86
# 4                    Hobart      AU    -42.88     147.33     11.11        66
# ..                      ...     ...       ...        ...       ...       ...
# 546             Brownsville      US     25.90     -97.50     28.33        78
# 547            Kruisfontein      ZA    -34.00      24.73      4.88        75
# 548  Madīnat Sittah Uktūbar      EG     29.82      31.05     25.00        83
# 549                     Diu      IN     20.71      70.98     30.10        73
# 550               Nantucket      US     41.28     -70.10     19.44        88
#
#      Cloudiness  Wind Speed      Date
# 0            90        6.20  07/15/20
# 1            75        1.50  07/15/20
# 2             4        1.34  07/15/20
# 3            35        4.78  07/15/20
# 4            75        0.50  07/15/20
# ..          ...         ...       ...
# 546           1        6.20  07/15/20
# 547           0        3.29  07/15/20
# 548          40        2.10  07/15/20
# 549         100        5.72  07/15/20
# 550          90        5.70  07/15/20
#
# [551 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Checking what the max humidity is
weather_data_df['Humidity'].max()

# Since no cities have humidity > 100, weather_data is clean data
# Out:
# 100

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  pimentel  -6.84  -79.93     66.20        29          75        5.82
# 1  victoria  22.29  114.16     69.01        88          40       18.34
# 2    padang  -0.95  100.35     79.90        75          99        1.63
# 3    hasaki  35.73  140.83     55.00       100          75        4.70
# 4   kahului  20.89 -156.47     70.00        88           1        7.63
#
#   Country        Date
# 0      PE  1585764415
# 1      HK  1585764288
# 2      ID  1585764115
# 3      JP  1585764415
# 4      US  1585764415

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create scatter plot of weight and mean tumor volume with configuration
weather_date = weather_data_df['Date'][0]

plt.scatter(
    weather_data_df['Latitude'], 
    weather_data_df['Max Temp'],
    marker="o",  
    edgecolors="black")

plt.title(f'City Latitude vs. Temperature {weather_date}')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)

plt.savefig('Figures/Latitude Vs Temperature.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create scatter plot of weight and mean tumor volume with configuration
plt.scatter(
    weather_data_df['Latitude'], 
    weather_data_df['Humidity'],
    marker="o",  
    edgecolors="black")

plt.title(f'City Latitude vs. Humidity {weather_date}')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

plt.savefig('Figures/Latitude Vs Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create scatter plot of weight and mean tumor volume with configuration
plt.scatter(
    weather_data_df['Latitude'], 
    weather_data_df['Cloudiness'],
    marker="o",  
    edgecolors="black")

plt.title(f'City Latitude vs. Cloudiness {weather_date}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

plt.savefig('Figures/Latitude Vs Cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create scatter plot of weight and mean tumor volume with configuration
plt.scatter(
    weather_data_df['Latitude'], 
    weather_data_df['Wind Speed'],
    marker='o',  
    edgecolors='black')

plt.title(f'City Latitude vs. Wind Speed {weather_date}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

plt.savefig('Figures/Latitude Vs Wind Speed.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

def line_regress_plot(x_values, y_values,x_label, y_label, hem, x_ann, y_ann):
    '''Creates a linear regression plot'''
    '''Parameters: x_values = x-axis values, 
                   y_values = x-axis values,
                   x_label, y_label = Axis lables,
                   hem = hemisphere (Northern, Southern)
                   x_ann, y_ann = regression line location'''
    
    # Define date of Weather
    weather_date = weather_data_df['Date'][0]
    #Define file name
    file_name = f'{hem}_Hem {x_label} vs. {y_label}.png'
        
    # Calculate and add linear regression equation to the scatter plot
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    regress_values = x_values * slope + intercept
    line_eqn = f'Y = {str(round(slope,2))}x + {str(round(intercept,2))}'

    plt.scatter(x_values,y_values, edgecolor='black', facecolor='blue', alpha=0.5)
    plt.plot(x_values,regress_values,'r-')
    plt.annotate(line_eqn,(x_ann,y_ann),fontsize=15,color='red')
    plt.title(f'{hem} Hemisphere\nCity {x_label} vs. {y_label} {weather_date}')
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    print(f'The r-squared is: {rvalue**2}')
    print(f'The regression line equation is: {line_eqn}')
    
    plt.savefig(f'Figures/{file_name}')
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hem = weather_data_df.loc[weather_data_df['Latitude'] > 0]
southern_hem = weather_data_df.loc[weather_data_df['Latitude'] < 0]
northern_hem
# Out:
#                        City Country  Latitude  Longitude  Max Temp  Humidity  \
# 0                    Barrow      US     71.29    -156.79      3.00        86
# 3                São Filipe      CV     14.90     -24.50     24.57        86
# 5                  Buraidah      SA     26.33      43.98     29.00        32
# 11             Saint George      US     37.10    -113.58     33.00        15
# 12              Provideniya      RU     64.38    -173.30      9.00        93
# ..                      ...     ...       ...        ...       ...       ...
# 545                 Kushiro      JP     42.98     144.37     16.00        77
# 546             Brownsville      US     25.90     -97.50     28.33        78
# 548  Madīnat Sittah Uktūbar      EG     29.82      31.05     25.00        83
# 549                     Diu      IN     20.71      70.98     30.10        73
# 550               Nantucket      US     41.28     -70.10     19.44        88
#
#      Cloudiness  Wind Speed      Date
# 0            90        6.20  07/15/20
# 3            35        4.78  07/15/20
# 5             0        3.10  07/15/20
# 11            1        2.60  07/15/20
# 12           90        4.00  07/15/20
# ..          ...         ...       ...
# 545          75        3.60  07/15/20
# 546           1        6.20  07/15/20
# 548          40        2.10  07/15/20
# 549         100        5.72  07/15/20
# 550          90        5.70  07/15/20
#
# [380 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
line_regress_plot(northern_hem['Latitude'], northern_hem['Max Temp'],'Latitude', 'Max Temperature (C)', 'Northern', 10, 8)
# Out:
# The r-squared is: 0.3773473561128384
# The regression line equation is: Y = -0.24x + 30.85

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
line_regress_plot(southern_hem['Latitude'], southern_hem['Max Temp'],'Latitude', 'Max Temperature (C)', 'Southern', -55, 25)
# Out:
# The r-squared is: 0.527983090896504
# The regression line equation is: Y = 0.45x + 26.23

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
line_regress_plot(northern_hem['Latitude'], northern_hem['Humidity'],'Latitude', 'Humidity (%)', 'Northern', 48, 10)
# Out:
# The r-squared is: 1.673784397383155e-05
# The regression line equation is: Y = 0.0x + 71.67

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
line_regress_plot(southern_hem['Latitude'], southern_hem['Humidity'],'Latitude', 'Humidity (%)', 'Southern', -55, 20)
# Out:
# The r-squared is: 0.01256603287929562
# The regression line equation is: Y = 0.15x + 75.88

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
line_regress_plot(northern_hem['Latitude'], northern_hem['Cloudiness'],'Latitude', 'Cloudiness (%)', 'Northern', 47, 62)
# Out:
# The r-squared is: 0.005833357522635008
# The regression line equation is: Y = 0.15x + 47.13

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
line_regress_plot(southern_hem['Latitude'], southern_hem['Cloudiness'],'Latitude', 'Cloudiness (%)', 'Southern', -55, 40)
# Out:
# The r-squared is: 0.007777534068902897
# The regression line equation is: Y = 0.25x + 43.12

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
line_regress_plot(northern_hem['Latitude'], northern_hem['Wind Speed'],'Latitude', 'Wind Speed (mph)', 'Northern', 15, 10)
# Out:
# The r-squared is: 5.596215992431832e-07
# The regression line equation is: Y = -0.0x + 3.36

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
line_regress_plot(southern_hem['Latitude'], southern_hem['Wind Speed'],'Latitude', 'Wind Speed (mph)', 'Southern', -50, 10)
# Out:
# The r-squared is: 0.006287211983903065
# The regression line equation is: Y = -0.01x + 2.74
